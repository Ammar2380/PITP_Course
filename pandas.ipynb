# %%
import pandas as pd

# %%
a = {
    "Name":["Arham","Ameen","Ammar"],
    "profession" : ["development" , "designer" , "marketing"],
    "city" : ["hyd","karachi","Lahore"]

}
print(a)
# Out:
# {'Name': ['Arham', 'Ameen', 'Ammar'], 'profession': ['development', 'designer', 'marketing'], 'city': ['hyd', 'karachi', 'Lahore']}

# %%
b = pd.DataFrame(a)

# %%
b
# Out:
#     Name   profession     city
# 0  Arham  development      hyd
# 1  Ameen     designer  karachi
# 2  Ammar    marketing   Lahore

# %%
b["gender"] = ["male","male","male"]

# %%
b
# Out:
#     Name   profession     city gender
# 0  Arham  development      hyd   male
# 1  Ameen     designer  karachi   male
# 2  Ammar    marketing   Lahore   male

# %%
b["Age"] = [33,32,32]

# %%
b
# Out:
#     Name   profession     city gender  Age
# 0  Arham  development      hyd   male   33
# 1  Ameen     designer  karachi   male   32
# 2  Ammar    marketing   Lahore   male   32

# %%
b[b["Age"]>20]
# Out:
#     Name   profession     city gender  Age
# 0  Arham  development      hyd   male   33
# 1  Ameen     designer  karachi   male   32
# 2  Ammar    marketing   Lahore   male   32

# %%
st = {
    "Name":["Arham","Ameen","Ammar","Khan","Ali"],
    "Obtain" : [80 , 23 , 32,60,26],
    "Total_Marks" : [100,100,100,100,100]

}

# %%
df = pd.DataFrame(st)

# %%
df["Percentage"] = (df["Obtain"] / df["Total_Marks"]) * 100

# %%
df
# Out:
#     Name  Obtain  Total_Marks  Percentage
# 0  Arham      80          100        80.0
# 1  Ameen      23          100        23.0
# 2  Ammar      32          100        32.0
# 3   Khan      60          100        60.0
# 4    Ali      26          100        26.0

# %%
titanic_data
