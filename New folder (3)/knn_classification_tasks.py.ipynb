# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

X = np.array([[30], [35], [40], [50], [60], [70], [80]]) 
y = np.array([0, 0, 1, 1, 1, 1, 1])

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

prediction = knn.predict([[65]])
print(f"65 marks result: {'Pass' if prediction[0] == 1 else 'Fail'}")
X = [[150, 1], [170, 1], [140, 1], [120, 2], [110, 2], [130, 2]]
y = ['Apple', 'Apple', 'Apple', 'Banana', 'Banana', 'Banana']

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

new_fruit = [[125, 2]]
print(f"Fruit prediction: {knn.predict(new_fruit)[0]}")

X = [[150, 1], [170, 1], [140, 1], [120, 2], [110, 2], [130, 2]]
y = ['Apple', 'Apple', 'Apple', 'Banana', 'Banana', 'Banana']

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

# New fruit: 125g and Yellow(2)
new_fruit = [[125, 2]]
print(f"Fruit prediction: {knn.predict(new_fruit)[0]}")
X = np.array([[i] for i in range(1, 21)])
y = np.array([0 if i % 2 == 0 else 1 for i in range(1, 21)]) # 0=Even, 1=Odd

knn = KNeighborsClassifier(n_neighbors=1) # 1 neighbor is best for patterns
knn.fit(X, y)

num = 17
pred = knn.predict([[num]])
print(f"Number {num} is: {'Odd' if pred[0] == 1 else 'Even'}")
# Experience in years
X = [[1], [2], [3], [5], [6], [8], [10], [12]]
y = ['Low', 'Low', 'Medium', 'Medium', 'Medium', 'High', 'High', 'High']

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

exp = [[4]]
print(f"Salary for {exp[0][0]} years: {knn.predict(exp)[0]}")
X = [[150], [155], [160], [170], [175], [180]]
y = ['Female', 'Female', 'Female', 'Male', 'Male', 'Male']

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

new_height = [[168]]
print(f"Gender prediction: {knn.predict(new_height)[0]}")
import matplotlib.pyplot as plt

X = [[1, 2], [2, 3], [3, 1], [6, 7], [7, 8], [8, 6]]
y = ['Class A', 'Class A', 'Class A', 'Class B', 'Class B', 'Class B']

nn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

new_point = [[5, 5]]
pred = knn.predict(new_point)

print(f"Point (5,5) belongs to: {pred[0]}")


plt.scatter([p[0] for p in X], [p[1] for p in X], c=['red' if label=='Class A' else 'blue' for label in y])
plt.scatter(5, 5, color='green', marker='x') 
plt.show()
# Out:
# 65 marks result: Pass
# Fruit prediction: Banana
# Fruit prediction: Banana
# Number 17 is: Odd
# Salary for 4 years: Medium
# Gender prediction: Male
# Point (5,5) belongs to: Class B
